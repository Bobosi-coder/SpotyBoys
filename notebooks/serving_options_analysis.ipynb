# %% [markdown]
# # Serving Options Analysis
# Run `scripts/benchmark_serving.py` on your Chameleon instance for each endpoint and enter the results below to generate the final table.

# %%
import pandas as pd

data = [
    {'Option': 'baseline_http', 'Endpoint URL': 'http://127.0.0.1:8000/predict', 'Model version': 'un-trained CNN14', 'Hardware': 'CPU', 'p50/p95 latency': 'TBD', 'Throughput': 'TBD', 'Error rate': 'TBD', 'Concurrency tested': 10, 'Compute instance type': 'compute_icelake', 'Notes': 'FastAPI basic'},
    {'Option': 'onnx_cpu', 'Endpoint URL': 'http://127.0.0.1:8001/predict', 'Model version': 'un-trained ONNX', 'Hardware': 'CPU', 'p50/p95 latency': 'TBD', 'Throughput': 'TBD', 'Error rate': 'TBD', 'Concurrency tested': 10, 'Compute instance type': 'compute_icelake', 'Notes': 'ONNX Runtime CPU'},
    {'Option': 'triton_batching', 'Endpoint URL': 'http://127.0.0.1:8002/predict', 'Model version': 'un-trained ONNX', 'Hardware': 'CPU', 'p50/p95 latency': 'TBD', 'Throughput': 'TBD', 'Error rate': 'TBD', 'Concurrency tested': 10, 'Compute instance type': 'compute_icelake', 'Notes': 'Triton Dynamic Batching'},
    {'Option': 'ray_serve', 'Endpoint URL': 'http://127.0.0.1:8003/predict', 'Model version': 'un-trained CNN14', 'Hardware': 'CPU', 'p50/p95 latency': 'TBD', 'Throughput': 'TBD', 'Error rate': 'TBD', 'Concurrency tested': 10, 'Compute instance type': 'compute_icelake', 'Notes': 'Ray Serve Bonus'}
]

df = pd.DataFrame(data)
display(df)

with open('serving_options_table.md', 'w') as f:
    f.write(df.to_markdown(index=False))
print('Saved rendering to serving_options_table.md')
